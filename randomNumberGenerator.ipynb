# %%
import random

# %% [markdown]
# # Perfect Random File

# %%
randomList = []
counter = 0

while counter < 1000:
    rand = random.uniform(0,2)
    temp = str(counter)+ ", "+str(rand)+", "+str(rand)
#     temp.join(", ")
  
#     temp = [str(counter", ",str(rand)", "str(rand))]
#     counter += 1
    randomList.append(temp)
    print (temp)
    counter+=1
# Out:
# 0, 0.7433487571281443, 0.7433487571281443
# 1, 1.0881289424911376, 1.0881289424911376
# 2, 1.3267970663640636, 1.3267970663640636
# 3, 0.6882564312225417, 0.6882564312225417
# 4, 1.215104658049054, 1.215104658049054
# 5, 0.39441155472416867, 0.39441155472416867
# 6, 1.9162860588641322, 1.9162860588641322
# 7, 1.4387241900201901, 1.4387241900201901
# 8, 1.1875782959104144, 1.1875782959104144
# 9, 1.9243676145949742, 1.9243676145949742
# 10, 1.9930956724384226, 1.9930956724384226
# 11, 0.36873814517674663, 0.36873814517674663
# 12, 0.003232726310464784, 0.003232726310464784
# 13, 0.9737215403315276, 0.9737215403315276
# 14, 1.8858084023832162, 1.8858084023832162
# 15, 1.2308570541564343, 1.2308570541564343
# 16, 0.5786279521052053, 0.5786279521052053
# 17, 1.7449143616238771, 1.7449143616238771
# 18, 0.6959110996047402, 0.6959110996047402
# 19, 0.4754526616616903, 0.4754526616616903
# 20, 1.603762136543748, 1.603762136543748
# 21, 1.278406870079077, 1.278406870079077
# ...

# %%
# places = ['Berlin', 'Cape Town', 'Sydney', 'Moscow']

with open('randomPerfect.txt', 'w') as filehandle:
    for listitem in randomList:
        filehandle.write('%s\n' % listitem)

# %%
temp= temp.join("4")

# %% [markdown]
# # 1,1 file

# %%
oneList = []
counter = 0

while counter < 1000:
#     rand = random.uniform(0,2)
    temp = str(counter)+ ", "+str(1)+", "+str(1)
#     temp.join(", ")
  
#     temp = [str(counter", ",str(rand)", "str(rand))]
#     counter += 1
    oneList.append(temp)
#     print (temp)
    counter+=1

# %%
with open('oneFile.txt', 'w') as filehandle:
    for listitem in oneList:
        filehandle.write('%s\n' % listitem)

# %% [markdown]
# # randomBad

# %%
randomBad = []
counter = 0

while counter < 1000:
#     rand = random.uniform(0,2)
    temp = str(counter)+ ", "+str(random.uniform(0,2))+", "+str(random.uniform(0,2))
#     temp.join(", ")
  
#     temp = [str(counter", ",str(rand)", "str(rand))]
#     counter += 1
    randomBad.append(temp)
#     print (temp)
    counter+=1

# %%
with open('randomBad.txt', 'w') as filehandle:
    for listitem in randomBad:
        filehandle.write('%s\n' % listitem)

# %% [markdown]
# # runningAvg

# %%
randomAvg = []
counter = 0
runningAvgSum = 0
while counter < 1001:
    realRandVal = random.uniform(0,2)
    if counter == 0:
        runingAvg = 0
    else:
        runingAvg = runningAvgSum/counter
        
    temp = str(counter)+", "+str(runingAvg)+ ", "+str(realRandVal)
    runningAvgSum += realRandVal
    randomAvg.append(temp)
#     print (temp)
    counter+=1

# %%
randomAvg
# Out:
# ['0, 0, 1.3489827966576058',
#  '1, 1.3489827966576058, 0.45550563500203567',
#  '2, 0.9022442158298207, 1.0324046686602772',
#  '3, 0.9456310334399728, 0.7006975555054695',
#  '4, 0.884397663956347, 1.162414533662302',
#  '5, 0.9400010378975381, 0.6873779014946619',
#  '6, 0.897897181830392, 1.4162789586728421',
#  '7, 0.9719517213793135, 0.623425657943455',
#  '8, 0.9283859634498313, 0.15376134595394086',
#  '9, 0.8423165615058434, 0.643049790381669',
#  '10, 0.822389884393426, 0.7519937502569838',
#  '11, 0.8159902358355676, 1.0947044678351314',
#  '12, 0.8392164218355312, 1.1959667510368164',
#  '13, 0.8666587548510147, 1.060325481544349',
#  '14, 0.8804920924719671, 0.880896074657898',
#  '15, 0.8805190246176958, 1.4218630332218267',
#  '16, 0.914353025155454, 0.43338605561315724',
#  '17, 0.8860608504764954, 0.634983618666604',
#  '18, 0.8721121153759459, 1.1434088185816838',
#  '19, 0.8863908892288795, 0.4852637968258089',
#  '20, 0.866334534608726, 0.2601272302050608',
# ...

# %%
with open('randomAvg.txt', 'w') as filehandle:
    for listitem in randomBad:
        filehandle.write('%s\n' % listitem)
